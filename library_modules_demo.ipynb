# %% [markdown]
# ### The Python Standard Library
# The standard library is distributed with Python.
#
# Python’s standard library is very extensive, offering a wide range of facilities as indicated by the long table of contents listed below.
#
# The library contains built-in modules (written in C) that provide access to system functionality such as file I/O that would otherwise be inaccessible to Python programmers, as well as modules written in Python that provide standardized solutions for many problems that occur in everyday programming.
#
#
# ### Built-in Functions
# The Python interpreter has a number of functions and types built into it that are always available. They are listed here in alphabetical order.
# ![image.png](attachment:image.png)

# %% [markdown]
# https://docs.python.org/3/library/functions.html

# %%
'''
dir([object]) - Without arguments, return the list of names in the current local scope. 
              With an argument, attempt to return a list of valid attributes for that object.
'''
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'exit',
#  'get_ipython',
#  'quit']

# %%
import math
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc']

# %%
#Convert an integer number to a binary string prefixed with “0b”.
bin(16)
# Out:
# '0b10000'

# %% [markdown]
# ### List all packages installed
# You can use help function in python to get the list of modules installed.

# %%
help("modules")
# Out:
# Please wait a moment while I gather a list of all available modules...
# C:\Users\DELL\anaconda3\lib\site-packages\IPython\kernel\__init__.py:12: ShimWarning: The `IPython.kernel` package has been deprecated since IPython 4.0.You should import from ipykernel or jupyter_client instead.
#   warn("The `IPython.kernel` package has been deprecated since IPython 4.0."
# C:\Users\DELL\anaconda3\lib\pkgutil.py:92: MatplotlibDeprecationWarning:
# The matplotlib.compat module was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
#   __import__(info.name)
# C:\Users\DELL\anaconda3\lib\site-packages\nltk\twitter\__init__.py:21: UserWarning: The twython library has not been installed. Some functionality from the twitter package will not be available.
#   warnings.warn(
# Warming up PyWSD (takes ~10 secs)... took 4.865448236465454 secs.
# C:\Users\DELL\anaconda3\lib\site-packages\skimage\morphology\_skeletonize.py:241: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   0, 1, 1, 0, 0, 1, 0, 0, 0], dtype=np.bool)
# C:\Users\DELL\anaconda3\lib\site-packages\skimage\morphology\_skeletonize.py:256: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   0, 0, 0, 0, 0, 0, 0, 0, 0], dtype=np.bool)
# C:\Users\DELL\anaconda3\lib\site-packages\skimage\viewer\utils\__init__.py:1: UserWarning: Recommended matplotlib backend is `Agg` for full skimage.viewer functionality.
#   from .core import *
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:33: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from ._gradient_boosting import predict_stages
# C:\Users\DELL\anaconda3\lib\site-packages\sklearn\ensemble\_gb.py:33: DeprecationWarning: `np.bool` is a deprecated alias for the builtin `bool`. To silence this warning, use `bool` by itself. Doing this will not modify any behavior and is safe. If you specifically wanted the numpy scalar type, use `np.bool_` here.
# Deprecated in NumPy 1.20; for more details and guidance: https://numpy.org/devdocs/release/1.20.0-notes.html#deprecations
#   from ._gradient_boosting import predict_stages
# C:\Users\DELL\anaconda3\lib\site-packages\qtawesome\iconic_font.py:311: UserWarning: You need to have a running QApplication to use QtAwesome!
#   warnings.warn("You need to have a running "
# C:\Users\DELL\anaconda3\lib\site-packages\tables\__init__.py:24: DeprecationWarning: `np.typeDict` is a deprecated alias for `np.sctypeDict`.
#   from .utilsextension import (
# C:\Users\DELL\anaconda3\lib\site-packages\tables\__init__.py:24: DeprecationWarning: `np.typeDict` is a deprecated alias for `np.sctypeDict`.
#   from .utilsextension import (
# C:\Users\DELL\anaconda3\lib\site-packages\zmq\auth\asyncio\__init__.py:26: DeprecationWarning: "@coroutine" decorator is deprecated since Python 3.8, use "async def" instead
#   def __handle_zap(self):
# C:\Users\DELL\anaconda3\lib\pkgutil.py:107: VisibleDeprecationWarning: zmq.eventloop.minitornado is deprecated in pyzmq 14.0 and will be removed.
#     Install tornado itself to use zmq with the tornado IOLoop.
#
#   yield from walk_packages(path, info.name+'.', onerror)
# Cython              brain_typing        matplotlib          snowballstemmer
# Hello_World         brain_uuid          mccabe              socket
# IPython             brotli              menuinst            socketserver
# OpenSSL             bs4                 mimetypes           socks
# PIL                 builtins            mistune             sockshandler
# PyQt5               bz2                 mkl                 sortedcollections
# __future__          cProfile            mkl_fft             sortedcontainers
# _abc                cachetools          mkl_random          soupsieve
# _ast                calendar            mmap                spacy
# _asyncio            catalogue           mmapfile            spacy_legacy
# _bisect             certifi             mmsystem            sphinx
# _blake2             cffi                mock                sphinxcontrib
# _bootlocale         cgi                 modulefinder        spyder
# _bz2                cgitb               more_itertools      spyder_kernels
# _cffi_backend       chardet             mpmath              sqlalchemy
# _codecs             charset_normalizer  msgpack             sqlite3
# _codecs_cn          chunk               msilib              sre_compile
# _codecs_hk          click               msvcrt              sre_constants
# _codecs_iso2022     click_config_file   multidict           sre_parse
# _codecs_jp          click_plugins       multipledispatch    srsly
# _codecs_kr          cloudpickle         multiprocessing     ssl
# _codecs_tw          clyent              murmurhash          sspi
# _collections        cmath               nacl                sspicon
# _collections_abc    cmd                 navigator_updater   stat
# _compat_pickle      code                nbclient            statistics
# _compression        codecs              nbconvert           statsmodels
# _contextvars        codeop              nbformat            storemagic
# _csv                collections         nest_asyncio        string
# _ctypes             colorama            netbios             stringprep
# _ctypes_test        colorsys            netrc               struct
# _datetime           commctrl            networkx            subprocess
# _decimal            compileall          nltk                sunau
# _distutils_hack     comtypes            nntplib             swiglpk
# _dummy_thread       concurrent          nose                symbol
# _elementtree        conda               notebook            sympy
# _functools          conda_build         nt                  sympyprinting
# _hashlib            conda_env           ntpath              symtable
# _heapq              conda_package_handling ntsecuritycon       sys
# _imp                conda_verify        nturl2path          sysconfig
# _io                 configobj           numba               tables
# _json               configparser        numbers             tabnanny
# _locale             contextlib          numexpr             tarfile
# _lsprof             contextlib2         numpy               tblib
# _lzma               contextvars         numpydoc            telnetlib
# _markupbase         copy                oauthlib            tempfile
# _md5                copyreg             odbc                terminado
# _msi                crypt               olefile             test
# _multibytecodec     cryptography        opcode              test_data
# _multiprocessing    csv                 openpyxl            test_pycosat
# _nsis               ctypes              operator            testpath
# _opcode             curl                optparse            tests
# _operator           curses              os                  textacy
# _osx_support        cwp                 packaging           textwrap
# _overlapped         cycler              pandas              thinc
# _pickle             cymem               pandocfilters       this
# _py_abc             cython              paramiko            threading
# _pydecimal          cythonmagic         parser              threadpoolctl
# _pyio               cytoolz             parso               tifffile
# _pyrsistent_version dask                partd               time
# _pytest             dataclasses         past                timeit
# _queue              datetime            path                timer
# _random             dateutil            pathlib             tkinter
# _sha1               dbi                 pathlib2            tlz
# _sha256             dbm                 pathtools           token
# _sha3               dde                 pathy               tokenize
# _sha512             decimal             patsy               toml
# _signal             decorator           pdb                 toolz
# _sitebuiltins       defusedxml          pep8                tornado
# _socket             diff_match_patch    perfmon             tqdm
# _sqlite3            difflib             pexpect             trace
# _sre                dis                 pickle              traceback
# _ssl                distributed         pickleshare         tracemalloc
# _stat               distutils           pickletools         traitlets
# _statistics         doctest             pip                 tty
# _string             docutils            pipes               turtle
# _strptime           dummy_threading     pkg_resources       turtledemo
# _struct             easy_install        pkginfo             twarc
# _symtable           email               pkgutil             twitter
# _system_path        en_core_web_sm      platform            typer
# _testbuffer         encodings           plistlib            types
# _testcapi           ensurepip           pluggy              typing
# _testconsole        entrypoints         ply                 typing_extensions
# _testimportmultiple enum                poplib              ujson
# _testinternalcapi   errno               posixpath           unicodecsv
# _testmultiphase     et_xmlfile          pprint              unicodedata
# _thread             fastcache           preprocessor        unittest
# _threading_local    faulthandler        preshed             urllib
# _tkinter            filecmp             profile             urllib3
# _tracemalloc        fileinput           prometheus_client   uu
# _version            filelock            prompt_toolkit      uuid
# _warnings           flake8              pstats              validate
# _weakref            flask               psutil              venv
# _weakrefset         fnmatch             pty                 warnings
# _win32sysloader     formatter           pvectorc            wasabi
# _winapi             fractions           py                  watchdog
# _winxptheme         fsspec              pyLDAvis            wave
# _xxsubinterpreters  ftplib              py_compile          wcwidth
# _yaml               functools           pyasn1              weakref
# abc                 funcy               pyasn1_modules      webbrowser
# adodbapi            future              pyclbr              webencodings
# afxres              gc                  pycodestyle         werkzeug
# aifc                genericpath         pycosat             wheel
# aiohttp             gensim              pycparser           widgetsnbextension
# alabaster           getopt              pycurl              win2kras
# anaconda_navigator  getpass             pydantic            win32api
# anaconda_project    gettext             pydoc               win32clipboard
# antigravity         gevent              pydoc_data          win32com
# argh                glob                pydocstyle          win32con
# argon2              glob2               pyexpat             win32console
# argparse            gmplot              pyflakes            win32cred
# array               google_crc32c       pygments            win32crypt
# asn1crypto          greenlet            pylab               win32cryptcon
# ast                 gzip                pylint              win32ctypes
# astroid             h5py                pyls                win32event
# astropy             hashlib             pyls_jsonrpc        win32evtlog
# async_generator     hdbscan             pymprog             win32evtlogutil
# async_timeout       heapdict            pyodbc              win32file
# asynchat            heapq               pyparsing           win32gui
# asyncio             hmac                pyphen              win32gui_struct
# asyncore            html                pyreadline          win32help
# atexit              html5lib            pyrsistent          win32inet
# atomicwrites        http                pytest              win32inetcon
# attr                humanize            pythoncom           win32job
# audioop             idlelib             pytz                win32lz
# autopep8            idna                pywin               win32net
# autoreload          imageio             pywin32_bootstrap   win32netcon
# babel               imagesize           pywin32_testutil    win32pdh
# backcall            imaplib             pywintypes          win32pdhquery
# backports           imghdr              pywsd               win32pdhutil
# base64              imp                 pywt                win32pipe
# bcrypt              importlib           pyximport           win32print
# bdb                 importlib_metadata  qdarkstyle          win32process
# binascii            iniconfig           qtawesome           win32profile
# binhex              inspect             qtconsole           win32ras
# binstar_client      intervaltree        qtpy                win32rcparser
# bisect              io                  queue               win32security
# bitarray            ipaddress           quopri              win32service
# bkcharts            ipykernel           random              win32serviceutil
# bleach              ipykernel_launcher  rasutil             win32timezone
# blinker             ipython_genutils    re                  win32trace
# blis                ipywidgets          readline            win32traceutil
# bokeh               isapi               regcheck            win32transaction
# boto                isort               regex               win32ts
# boto3               isympy              regutil             win32ui
# botocore            itertools           reprlib             win32uiole
# bottleneck          itsdangerous        requests            win32verstamp
# brain_argparse      jdcal               requests_oauthlib   win32wnet
# brain_attrs         jedi                rlcompleter         win_inet_pton
# brain_boto3         jellyfish           rmagic              win_unicode_console
# brain_builtin_inference jinja2              rope                wincertstore
# brain_collections   jmespath            rsa                 winerror
# brain_crypt         joblib              rtree               winioctlcon
# brain_curses        json                ruamel_yaml         winnt
# brain_dataclasses   json5               run                 winperf
# brain_dateutil      jsonschema          runpy               winpty
# brain_fstrings      jupyter             s3transfer          winreg
# brain_functools     jupyter_client      sched               winsound
# brain_gi            jupyter_console     scipy               winxpgui
# brain_hashlib       jupyter_core        scripts             winxptheme
# brain_http          jupyterlab          seaborn             wn
# brain_io            jupyterlab_pygments secrets             wordcloud
# brain_mechanize     jupyterlab_server   select              wrapt
# brain_multiprocessing jwt                 selectors           wsgiref
# brain_namedtuple_enum keyring             send2trash          xdrlib
# brain_nose          keyword             servicemanager      xlrd
# brain_numpy_core_fromnumeric kiwisolver          setuptools          xlsxwriter
# brain_numpy_core_function_base lazy_object_proxy   shellingham         xlwings
# brain_numpy_core_multiarray lib2to3             shelve              xlwt
# brain_numpy_core_numeric libarchive          shlex               xml
# brain_numpy_core_numerictypes libfuturize         shutil              xmlrpc
# brain_numpy_core_umath libpasteurize       signal              xmltodict
# brain_numpy_ndarray lief                simplegeneric       xxsubtype
# brain_numpy_random_mtrand linecache           singledispatch      yaml
# brain_numpy_utils   llvmlite            singledispatch_helpers yapf
# brain_pkg_resources locale              sip                 yapftests
# brain_pytest        locket              sipconfig           yarl
# brain_qt            logging             sipdistutils        zict
# brain_random        lxml                site                zipapp
# brain_re            lzma                six                 zipfile
# brain_responses     mailbox             skimage             zipimport
# brain_scipy_signal  mailcap             sklearn             zipp
# brain_six           mapsplotlib         smart_open          zlib
# brain_ssl           markupsafe          smtpd               zmq
# brain_subprocess    marshal             smtplib             zope
# brain_threading     math                sndhdr
#
# Enter any module name to get more help.  Or, type "modules spam" to search
# for modules whose name or summary contain the string "spam".

# %%
help(math)
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\ipykernel\ipkernel.py:287: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Help on built-in module math:
#
# NAME
#     math
#
# DESCRIPTION
#     This module provides access to the mathematical functions
#     defined by the C standard.
#
# FUNCTIONS
#     acos(x, /)
#         Return the arc cosine (measured in radians) of x.
#
#     acosh(x, /)
#         Return the inverse hyperbolic cosine of x.
#
#     asin(x, /)
#         Return the arc sine (measured in radians) of x.
#
#     asinh(x, /)
#         Return the inverse hyperbolic sine of x.
#
#     atan(x, /)
#         Return the arc tangent (measured in radians) of x.
#
#     atan2(y, x, /)
#         Return the arc tangent (measured in radians) of y/x.
#
#         Unlike atan(y/x), the signs of both x and y are considered.
#
#     atanh(x, /)
#         Return the inverse hyperbolic tangent of x.
#
#     ceil(x, /)
#         Return the ceiling of x as an Integral.
#
#         This is the smallest integer >= x.
#
#     comb(n, k, /)
#         Number of ways to choose k items from n items without repetition and without order.
#
#         Evaluates to n! / (k! * (n - k)!) when k <= n and evaluates
#         to zero when k > n.
#
#         Also called the binomial coefficient because it is equivalent
#         to the coefficient of k-th term in polynomial expansion of the
#         expression (1 + x)**n.
#
#         Raises TypeError if either of the arguments are not integers.
#         Raises ValueError if either of the arguments are negative.
#
#     copysign(x, y, /)
#         Return a float with the magnitude (absolute value) of x but the sign of y.
#
#         On platforms that support signed zeros, copysign(1.0, -0.0)
#         returns -1.0.
#
#     cos(x, /)
#         Return the cosine of x (measured in radians).
#
#     cosh(x, /)
#         Return the hyperbolic cosine of x.
#
#     degrees(x, /)
#         Convert angle x from radians to degrees.
#
#     dist(p, q, /)
#         Return the Euclidean distance between two points p and q.
#
#         The points should be specified as sequences (or iterables) of
#         coordinates.  Both inputs must have the same dimension.
#
#         Roughly equivalent to:
#             sqrt(sum((px - qx) ** 2.0 for px, qx in zip(p, q)))
#
#     erf(x, /)
#         Error function at x.
#
#     erfc(x, /)
#         Complementary error function at x.
#
#     exp(x, /)
#         Return e raised to the power of x.
#
#     expm1(x, /)
#         Return exp(x)-1.
#
#         This function avoids the loss of precision involved in the direct evaluation of exp(x)-1 for small x.
#
#     fabs(x, /)
#         Return the absolute value of the float x.
#
#     factorial(x, /)
#         Find x!.
#
#         Raise a ValueError if x is negative or non-integral.
#
#     floor(x, /)
#         Return the floor of x as an Integral.
#
#         This is the largest integer <= x.
#
#     fmod(x, y, /)
#         Return fmod(x, y), according to platform C.
#
#         x % y may differ.
#
#     frexp(x, /)
#         Return the mantissa and exponent of x, as pair (m, e).
#
#         m is a float and e is an int, such that x = m * 2.**e.
#         If x is 0, m and e are both 0.  Else 0.5 <= abs(m) < 1.0.
#
#     fsum(seq, /)
#         Return an accurate floating point sum of values in the iterable seq.
#
#         Assumes IEEE-754 floating point arithmetic.
#
#     gamma(x, /)
#         Gamma function at x.
#
#     gcd(x, y, /)
#         greatest common divisor of x and y
#
#     hypot(...)
#         hypot(*coordinates) -> value
#
#         Multidimensional Euclidean distance from the origin to a point.
#
#         Roughly equivalent to:
#             sqrt(sum(x**2 for x in coordinates))
#
#         For a two dimensional point (x, y), gives the hypotenuse
#         using the Pythagorean theorem:  sqrt(x*x + y*y).
#
#         For example, the hypotenuse of a 3/4/5 right triangle is:
#
#             >>> hypot(3.0, 4.0)
#             5.0
#
#     isclose(a, b, *, rel_tol=1e-09, abs_tol=0.0)
#         Determine whether two floating point numbers are close in value.
#
#           rel_tol
#             maximum difference for being considered "close", relative to the
#             magnitude of the input values
#           abs_tol
#             maximum difference for being considered "close", regardless of the
#             magnitude of the input values
#
#         Return True if a is close in value to b, and False otherwise.
#
#         For the values to be considered close, the difference between them
#         must be smaller than at least one of the tolerances.
#
#         -inf, inf and NaN behave similarly to the IEEE 754 Standard.  That
#         is, NaN is not close to anything, even itself.  inf and -inf are
#         only close to themselves.
#
#     isfinite(x, /)
#         Return True if x is neither an infinity nor a NaN, and False otherwise.
#
#     isinf(x, /)
#         Return True if x is a positive or negative infinity, and False otherwise.
#
#     isnan(x, /)
#         Return True if x is a NaN (not a number), and False otherwise.
#
#     isqrt(n, /)
#         Return the integer part of the square root of the input.
#
#     ldexp(x, i, /)
#         Return x * (2**i).
#
#         This is essentially the inverse of frexp().
#
#     lgamma(x, /)
#         Natural logarithm of absolute value of Gamma function at x.
#
#     log(...)
#         log(x, [base=math.e])
#         Return the logarithm of x to the given base.
#
#         If the base not specified, returns the natural logarithm (base e) of x.
#
#     log10(x, /)
#         Return the base 10 logarithm of x.
#
#     log1p(x, /)
#         Return the natural logarithm of 1+x (base e).
#
#         The result is computed in a way which is accurate for x near zero.
#
#     log2(x, /)
#         Return the base 2 logarithm of x.
#
#     modf(x, /)
#         Return the fractional and integer parts of x.
#
#         Both results carry the sign of x and are floats.
#
#     perm(n, k=None, /)
#         Number of ways to choose k items from n items without repetition and with order.
#
#         Evaluates to n! / (n - k)! when k <= n and evaluates
#         to zero when k > n.
#
#         If k is not specified or is None, then k defaults to n
#         and the function returns n!.
#
#         Raises TypeError if either of the arguments are not integers.
#         Raises ValueError if either of the arguments are negative.
#
#     pow(x, y, /)
#         Return x**y (x to the power of y).
#
#     prod(iterable, /, *, start=1)
#         Calculate the product of all the elements in the input iterable.
#
#         The default start value for the product is 1.
#
#         When the iterable is empty, return the start value.  This function is
#         intended specifically for use with numeric values and may reject
#         non-numeric types.
#
#     radians(x, /)
#         Convert angle x from degrees to radians.
#
#     remainder(x, y, /)
#         Difference between x and the closest integer multiple of y.
#
#         Return x - n*y where n*y is the closest integer multiple of y.
#         In the case where x is exactly halfway between two multiples of
#         y, the nearest even value of n is used. The result is always exact.
#
#     sin(x, /)
#         Return the sine of x (measured in radians).
#
#     sinh(x, /)
#         Return the hyperbolic sine of x.
#
#     sqrt(x, /)
#         Return the square root of x.
#
#     tan(x, /)
#         Return the tangent of x (measured in radians).
#
#     tanh(x, /)
#         Return the hyperbolic tangent of x.
#
#     trunc(x, /)
#         Truncates the Real x to the nearest Integral toward 0.
#
#         Uses the __trunc__ magic method.
#
# DATA
#     e = 2.718281828459045
#     inf = inf
#     nan = nan
#     pi = 3.141592653589793
#     tau = 6.283185307179586
#
# FILE
#     (built-in)

# %% [markdown]
# #### Note: If the function arguments list ends with /.

# %%
# Example 1:
def foo(p1, p2, /):
    pass
   
# This means all functional arguments are positional.

# Example 2:

def foo(a, b, / , x, y):
    print("positional ", a, b)
    print("positional or keyword", x, y)

# %% [markdown]
# Here in the above function definition parameters a and b are positional-only, while x or y can be either positional or keyword.
#
# Following function calls are valid
#
# foo(40, 20, 99, 39)
#
# foo(40, 3.14, "hello", y="world")
#
# foo(1.45, 3.14, x="hello", y="world")
#
# But, following function call is not valid which raises an exception TypeError since a, b are not passed as positional arguments instead passed as keyword
#
# foo(a=1.45, b=3.14, x=1, y=4)

# %%
import math
dir(math)
# Out:
# ['__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  'acos',
#  'acosh',
#  'asin',
#  'asinh',
#  'atan',
#  'atan2',
#  'atanh',
#  'ceil',
#  'comb',
#  'copysign',
#  'cos',
#  'cosh',
#  'degrees',
#  'dist',
#  'e',
#  'erf',
#  'erfc',
#  'exp',
#  'expm1',
#  'fabs',
#  'factorial',
#  'floor',
#  'fmod',
#  'frexp',
#  'fsum',
#  'gamma',
#  'gcd',
#  'hypot',
#  'inf',
#  'isclose',
#  'isfinite',
#  'isinf',
#  'isnan',
#  'isqrt',
#  'ldexp',
#  'lgamma',
#  'log',
#  'log10',
#  'log1p',
#  'log2',
#  'modf',
#  'nan',
#  'perm',
#  'pi',
#  'pow',
#  'prod',
#  'radians',
#  'remainder',
#  'sin',
#  'sinh',
#  'sqrt',
#  'tan',
#  'tanh',
#  'tau',
#  'trunc']

# %% [markdown]
# ### random module
#
# https://github.com/python/cpython/blob/3.10/Lib/random.py
