# %% [markdown]
# ### Python Operators
# #### 1. ArithmeticOperators
#
# ![image-2.png](attachment:image-2.png)

# %%
# Float division returns a floating point approximation of the result of a division.
print("25/4   =",25 / 4)    

# The modulo operation(%) finds the remainder or signed remainder after the division of one number by another 
print("25%4   =",25 % 4)
print("25%4.5 =",25 % 4.5)

# Integer division returns the floor of the division. That is, the values after the decimal point 
# are discarded.
print("25//4  =",25 // 4)
print("27//4  =",27 // 4)
print("27//4.2=",27 // 4.2)
print("-(25//4) =",-(25 // 4))
print("-27//4 =",-27 // 4)
# Out:
# 25/4   = 6.25
# 25%4   = 1
# 25%4.5 = 2.5
# 25//4  = 6
# 27//4  = 6
# 27//4.2= 6.0
# -(25//4) = -6
# -27//4 = -7

# %% [markdown]
# #### 2. Python Assignment Operators
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 3. Python Bitwise Operators
# ![image.png](attachment:image.png)

# %%
a = 5 # 0101
b = 6 # 0110
print ("a & b ", a & b) # 0100  => 4
print ("a | b ", a | b) # 0111 => 7
print ("a ^ b ", a ^ b) # 0011 => 3
print ("a << 4 ", a << 4) # 0101 0000 => 80
print ("-16 >> 2 ", -16 >> 2) # 0100 1011 >> 3 => 0100 1 => 9
print ( "~ a ", ~a ) # 111111111 .... 1010 => -6
# Out:
# a & b  4
# a | b  7
# a ^ b  3
# a << 4  80
# -16 >> 2  -4
# ~ a  -6

# %% [markdown]
# #### 4. Python Comparison Operators
# ![image.png](attachment:image.png)

# %%
print("10 == 10 :", 10 == 10) # True
print("3 > 2 : ", 3 > 2) # True
# Out:
# 10 == 10 : True
# 3 > 2 :  True

# %%
# cascading comparison
# a op1 b op2 c is same as (a op1 b) and (b op2 c)
# Python knows math better than any other language!!

print("3 > 2 > 1 : ", 3 > 2 > 1)
print("10 == 10 == 10 : ", 10 == 10 == 10)
# Out:
# 3 > 2 > 1 :  True
# 10 == 10 == 10 :  True

# %%
# string comparison:
# compares the corresponding characters based on the coding - based how the character
#	is stored as a number in the computer - until a mismatch or one or both strings end.

print("cat > car : ", "cat" > "car") # True  # "t" > "r"
print("cat > cattle : ", "cat" > "cattle" ) # False : second string is longer and therefore  bigger
print("cat == Cat : ", "cat" == "Cat") # False : "C" < "c"
print("apple > z : ", "apple" > "z") # False ; comparison not based on the length
print("zebra > abcdefgh : ", "zebra" > "abcedefgh") # True "z" > a"; rest do not matter
# Out:
# cat > car :  True
# cat > cattle :  False
# cat == Cat :  False
# apple > z :  False
# zebra > abcdefgh :  True

# %%
# list comparison:
# rule same as that of string - compare the corresponding elements until a 
#  mismatch or one or both ends
print([10, 20, 30] > [10, 25]) # False  20 > 25 is false

print([(10, 20), "abcd" ] >[(10, 20), "abcc" ]) # True  d of abcd > last c of abcc
# Out:
# False
# True

# %% [markdown]
# #### 5. Python Membership Operators
#
# Membership operators are used to test if a sequence is presented in an object:
# ![image.png](attachment:image.png)

# %%
# in (membership operator) : used to test if a sequence is presented in an object
print("c in cat  : ", "c" in "cat")  #True
print("at in cat : ", "at" in "cat") # True

print("ct in cat : ", "ct" in "cat")  #False
print("ta in cat : ", "ta" in "cat")  #False


print("cat > cat : ","cat" > "cat")  # False
print("cat >= cat : ","cat" >= "cat") # True
# Out:
# c in cat  :  True
# at in cat :  True
# ct in cat :  False
# ta in cat :  False
# cat > cat :  False
# cat >= cat :  True

# %% [markdown]
# #### 6. Python Logical Operators
# Logical operators are used to combine conditional statements.
#
# These operators operate on boolean values.
# ![image.png](attachment:image.png)

# %%
# logical operators are used to combine conditional statements
#	not
#	and
#	or
# These operators operate on boolean values

a = 10
b = 10
print (not (a == b) )  # False
print(a > 5 or b > 5) # True
print(a > 5 or b < 5) # False
print(a < 5 or b < 5) # False
# Out:
# False
# True
# True
# False

# %%
a = 0
b = 10
#print( b / a > 5) # division by zero
#print( a == 0 and b / a > 5 )
print( a < 0 and b / a > 5 )
print( a == 0 and b==10 )

print( a == 0 or b / a > 5 )
print( a < 0 or b < 20 )
print( a < 0 or b < 10 )
# short circuit evaluation
#	evaluate a logical expression left to right
#	stop the evaluation as soon as the truth or the falsehood is found
# Out:
# False
# True
# True
# True
# False

# %% [markdown]
# #### 7. Python Identity Operators
# Identity operators are used to compare the objects, not if they are equal, but if they are actually the same object, with the same memory location:
# ![image.png](attachment:image.png)

# %%
x=10
y=10
print(x is y)
print(x is not y)

m=11
n=22
print(m is n)
print(m is not n)
# Out:
# True
# False
# False
# True

# %% [markdown]
# #### In Python, the following are true.
# True   5   -5   1   "python"   ["we", "love", "python"] (1,4,8)→ non-empty-data-structures
#
# #### In Python, the following are false.
#
# False   0   “”      None   [] () {} → empty-data-structures

# %%
x=0
if x:
    print(x, "is true")
else:
    print(x, "is false")
# Out:
# 0 is false

# %%
x=' '
if x:
    print(x, "is true")
else:
    print(x, "is false")
# Out:
#   is true

# %%
x={}
if x:
    print(x, "is true")
else:
    print(x, "is false")
# Out:
# {} is false

# %% [markdown]
# #### Polymorphic operators

# %%
# +
print(10 + 20) # 30
print("one" + "two") # onetwo # concatenation
print([10, 20] + [30, 40]) # [10, 20, 30, 40] # concatenation

# *
print(2 * 3) # 6
print("2" * 5) # 222 # replicate
print("python" * 3) # pythonpythonpython
print((10, 20) * 3)  #(10, 20, 10, 20, 10, 20)
print(3 * "2") # 222
# Out:
# 30
# onetwo
# [10, 20, 30, 40]
# 6
# 22222
# pythonpythonpython
# (10, 20, 10, 20, 10, 20)
# 222

# %% [markdown]
# #### The operator precedence in Python is listed in the following table. It is in descending order (upper group has higher precedence than the lower ones).
#
# ![image.png](attachment:image.png)

# %%
if( 0 and 2 or 1):
    print("Hi")
# Out:
# Hi
